# %%
(-> "🏠 " (str "Welcome to the Basilisp Kernel Exploration Notebook!"))
# Out:
# '🏠 Welcome to the Basilisp Kernel Exploration Notebook!'

# %% [markdown]
# ### 📚 The src/basapp library

# %%
(require '[basapp.core :refer [hello] :as bc])

# %%
(hello)
# Out:
# :Hi 👋 The Basilisp Kernel supports autocompletion of symbols using the Tab key ⌨️. Give it a go!

# %% [markdown]
# ##### 🌐 nREPL Server support ([💡guide](https://github.com/ikappaki/basilex-notebook/wiki/Connecting-Your-Editor-to-the-nREPL-Server))

# %%
(require '[basilisp-kernel.nrepl-server :refer [server-start]])

# %%
(def server (server-start {:port 9998}))
# Out:
# nREPL server started on port 9998 on host 127.0.0.1 - nrepl://127.0.0.1:9998
# #'user/server

# %%
(bc/slider)
# Out:
# 📝 Open the `basilisp.edn` file in your Clojure Editor and connect to the nREPL port above ([💡guide](https://github.com/ikappaki/basilex-notebook/wiki/Connecting-Your-Editor-to-the-nREPL-Server)). Then, open `src/basapp/core.lpy` and adjust the slider value by evaluating the forms in the `comment` block.
# IntSlider(value=26, description='Change from your Code Editor:', style=SliderStyle(description_width='initial'…

# %% [markdown]
# ### 🐍 Python [Interop](https://basilisp.readthedocs.io/en/latest/pyinterop.html) example with [Pandas🐼](https://www.w3schools.com/python/pandas/pandas_plotting.asp)

# %%
(import [pandas :as pd]) nil

# %%
(def air-quality (pd/read_csv "https://web.archive.org/web/20240429180538id_/https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv"
                              **
                              :index-col 0
                              :parse-dates true))
# Out:
# #'user/air-quality

# %%
(.plot air-quality ** :figsize [8 1.2])
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# ### 🧭 Start Exploring [Basilisp](https://basilisp.readthedocs.io/en/latest/) [Clojure](https://clojure.org/guides/learn/clojure)

# %%
(require '[basilisp.string :as str])

# %%
(->> "Let's go!" str/upper-case (str (reduce + [100 20 3]) " ") println)
# Out:
# 123 LET'S GO!
